# %%
import os
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))
chat = client.chats.create(model="gemini-2.5-flash")


def send_and_trim(user_text):
    global chat
    chat.send_message(user_text)

    current_history = chat.get_history()
    if len(current_history) > 10:
        trimmed_history = current_history[-10:]
        chat = client.chats.create(model="gemini-2.5-flash", history=trimmed_history)


send_and_trim("my name is rahul")
send_and_trim("what is my name?")

for message in chat.get_history():
    print(f"{message.role}: {message.parts[0].text}")
    print("-" * 20)
# Out:
# user: my name is rahul
# --------------------
# model: Okay, Rahul. Nice to meet you!
# --------------------
# user: what is my name?
# --------------------
# model: Your name is Rahul.
# --------------------

# %%
send_and_trim("what is my name?")

# %%
for message in chat.get_history():
    print(f"{message.role}: {message.parts[0].text}")
    print("-" * 20)
# Out:
# user: my name is rahul
# --------------------
# model: Okay, Rahul. Nice to meet you!
# --------------------
# user: what is my name?
# --------------------
# model: Your name is Rahul.
# --------------------
# user: what is my name?
# --------------------
# model: Your name is Rahul.
# --------------------

# %%
send_and_trim("i like table tennis")
for message in chat.get_history():
    print(f"{message.role}: {message.parts[0].text}")
    print("-" * 20)
# Out:
# user: my name is rahul
# --------------------
# model: Okay, Rahul. Nice to meet you!
# --------------------
# user: what is my name?
# --------------------
# model: Your name is Rahul.
# --------------------
# user: what is my name?
# --------------------
# model: Your name is Rahul.
# --------------------
# user: i like table tennis
# --------------------
# model: That's a great sport! Table tennis is a lot of fun, and a fantastic way to stay active.
#
# Do you play often?
# --------------------

# %%
send_and_trim("i like pubg mobile also")
for message in chat.get_history():
    print(f"{message.role}: {message.parts[0].text}")
    print("-" * 20)
# Out:
# user: my name is rahul
# --------------------
# model: Okay, Rahul. Nice to meet you!
# --------------------
# user: what is my name?
# --------------------
# model: Your name is Rahul.
# --------------------
# user: what is my name?
# --------------------
# model: Your name is Rahul.
# --------------------
# user: i like table tennis
# --------------------
# model: That's a great sport! Table tennis is a lot of fun, and a fantastic way to stay active.
#
# Do you play often?
# --------------------
# user: i like pubg mobile also
# --------------------
# model: Ah, PUBG Mobile! That's a very popular game. So you enjoy both the physical sport of table tennis and the strategic, fast-paced action of mobile gaming.
#
# Do you have a favorite map or weapon in PUBG Mobile?
# --------------------

# %%
send_and_trim("yes i do , it is erangel")
for message in chat.get_history():
    print(f"{message.role}: {message.parts[0].text}")
    print("-" * 20)
# Out:
# user: what is my name?
# --------------------
# model: Your name is Rahul.
# --------------------
# user: what is my name?
# --------------------
# model: Your name is Rahul.
# --------------------
# user: i like table tennis
# --------------------
# model: That's a great sport! Table tennis is a lot of fun, and a fantastic way to stay active.
#
# Do you play often?
# --------------------
# user: i like pubg mobile also
# --------------------
# model: Ah, PUBG Mobile! That's a very popular game. So you enjoy both the physical sport of table tennis and the strategic, fast-paced action of mobile gaming.
#
# Do you have a favorite map or weapon in PUBG Mobile?
# --------------------
# user: yes i do , it is erangel
# --------------------
# model: Erangel is a classic! It's definitely one of the most iconic and beloved maps in PUBG Mobile. It has such a good mix of terrains, cities, and open fields.
#
# ...

# %%
send_and_trim("yes i always land in pochinki")
for message in chat.get_history():
    print(f"{message.role}: {message.parts[0].text}")
    print("-" * 20)
# Out:
# user: what is my name?
# --------------------
# model: Your name is Rahul.
# --------------------
# user: i like table tennis
# --------------------
# model: That's a great sport! Table tennis is a lot of fun, and a fantastic way to stay active.
#
# Do you play often?
# --------------------
# user: i like pubg mobile also
# --------------------
# model: Ah, PUBG Mobile! That's a very popular game. So you enjoy both the physical sport of table tennis and the strategic, fast-paced action of mobile gaming.
#
# Do you have a favorite map or weapon in PUBG Mobile?
# --------------------
# user: yes i do , it is erangel
# --------------------
# model: Erangel is a classic! It's definitely one of the most iconic and beloved maps in PUBG Mobile. It has such a good mix of terrains, cities, and open fields.
#
# What do you like most about playing on Erangel? Is it a particular drop spot, or the overall feel of the map?
# --------------------
# user: yes i always land in pochinki
# ...

# %%
send_and_trim("yes it is quite a hot drop")
for message in chat.get_history():
    print(f"{message.role}: {message.parts[0].text}")
    print("-" * 20)
# Out:
# user: i like table tennis
# --------------------
# model: That's a great sport! Table tennis is a lot of fun, and a fantastic way to stay active.
#
# Do you play often?
# --------------------
# user: i like pubg mobile also
# --------------------
# model: Ah, PUBG Mobile! That's a very popular game. So you enjoy both the physical sport of table tennis and the strategic, fast-paced action of mobile gaming.
#
# Do you have a favorite map or weapon in PUBG Mobile?
# --------------------
# user: yes i do , it is erangel
# --------------------
# model: Erangel is a classic! It's definitely one of the most iconic and beloved maps in PUBG Mobile. It has such a good mix of terrains, cities, and open fields.
#
# What do you like most about playing on Erangel? Is it a particular drop spot, or the overall feel of the map?
# --------------------
# user: yes i always land in pochinki
# --------------------
# ...

# %%
send_and_trim("do you remmeber my name")
for message in chat.get_history():
    print(f"{message.role}: {message.parts[0].text}")
    print("-" * 20)
# Out:
# user: i like pubg mobile also
# --------------------
# model: Ah, PUBG Mobile! That's a very popular game. So you enjoy both the physical sport of table tennis and the strategic, fast-paced action of mobile gaming.
#
# Do you have a favorite map or weapon in PUBG Mobile?
# --------------------
# user: yes i do , it is erangel
# --------------------
# model: Erangel is a classic! It's definitely one of the most iconic and beloved maps in PUBG Mobile. It has such a good mix of terrains, cities, and open fields.
#
# What do you like most about playing on Erangel? Is it a particular drop spot, or the overall feel of the map?
# --------------------
# user: yes i always land in pochinki
# --------------------
# model: Pochinki! That's a bold choice! It's one of the most famous and action-packed hot drops on Erangel. You're guaranteed to find early fights there.
#
# What draws you to Pochinki every time? Do you enjoy the early intensity, or have you just mastered the layout of the town?
# ...
